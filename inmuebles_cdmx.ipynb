# %% [markdown]
# <a href="https://colab.research.google.com/github/AenimaLabs/2061-pandas-conociendo-la-biblioteca/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Importar y conocer la base de datos

# %% [markdown]
# ###Importar la base de datos

# %%
import pandas as pd

datos = pd.read_csv("/content/drive/MyDrive/alquiler.csv")
datos.head()
# Out:
#   Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0      Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                   Casa;Polanco;2;0;1;100;24500.0;;
# 2  Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3  Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4      Departamento;Del Valle;1;0;0;48;2800.0;805.0;

# %%
#por defecto la separación es por , pero en este caso viene con ;
datos = pd.read_csv("/content/drive/MyDrive/alquiler.csv", sep=";")
datos.head() #5 primeras filas
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail() #5 últimas filas
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(5) #muestra de manera aleatoria 10 filas
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25029        Edificio Completo       Villa de Cortés             0        0
# 9660              Departamento  Lomas de Chapultepec             1        0
# 14600             Departamento              Santa Fe             3        1
# 18942  Conjunto Comercial/Sala      Centro Histórico             0        0
# 23921             Departamento  Lomas de Chapultepec             4        3
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25029       0   600  22750.0         NaN       NaN
# 9660        1    45  10500.0      3115.0     332.5
# 14600       1    82   5950.0      2660.0    5320.0
# 18942       0   155  35000.0     27961.5    2786.0
# 23921       1   200  52500.0     11406.5    2163.0

# %%
type(datos) #qué cosa es datos
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###Saber más:
# read_csv(), read_excel(), read_json(), read_html(), read_sql()

# %% [markdown]
# ###Explorar características de los datos

# %%
datos.shape # entrega el tamaño de (filas, columnas) como tuplas
# Out:
# (25121, 9)

# %%
datos.columns #entrega una lista de los nombnres de las columnas
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info() #información general del dataframe, los object son del tipo string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos["Tipo"] #entrega una serie de la columna Tipo
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[["Habitaciones", "Valor"]] #doble paréntesis, es una lista
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# ##Análisis exploratorio de los datos

# %% [markdown]
# ###Valores promedio de alquiler por tipo de inmueble

# %%
datos.describe() #algunas estadísticas
# Out:
#        Habitaciones       Garages        Suites          Area         Valor  \
# count  25121.000000  25121.000000  25121.000000  25121.000000  2.510700e+04
# mean       1.748856      1.798655      0.656781    220.885076  3.688505e+04
# std        1.811131     22.906129      1.083180    817.465428  3.669381e+05
# min        0.000000      0.000000      0.000000      0.000000  3.150000e+02
# 25%        0.000000      0.000000      0.000000     55.000000  5.600000e+03
# 50%        2.000000      1.000000      0.000000     90.000000  1.137500e+04
# 75%        3.000000      2.000000      1.000000    180.000000  2.695000e+04
# max      100.000000   1966.000000     24.000000  42000.000000  5.250000e+07
#
#          Condominio      Impuesto
# count  2.249500e+04  1.803700e+04
# mean   9.528676e+03  4.436513e+03
# std    1.547102e+05  2.283381e+04
# min    3.500000e+00  3.500000e+00
# 25%    2.275000e+03  4.270000e+02
# 50%    4.056500e+03  1.008000e+03
# 75%    7.350000e+03  2.625000e+03
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos["Valor"].mean() #promedio de la columna Valor
# Out:
# np.float64(36885.05048392878)

# %%
#datos.groupby("Tipo").mean() #promedio de la columna Valor por tipo de inmueble
#da jugo porque la columna colonia es del tipo string

# %%
datos.groupby("Tipo").mean(numeric_only=True) #promedio de la columna Valor por tipo de inmueble
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
valor_promedio_tipo_serie = datos.groupby("Tipo")["Valor"].mean() #promedio de la columna Valor por tipo de inmueble
print(type(valor_promedio_tipo_serie)) #es una serie
valor_promedio_tipo_serie
# Out:
# <class 'pandas.core.series.Series'>
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# ...

# %%
valor_promedio_tipo_df = datos.groupby("Tipo")[["Valor"]].mean().sort_values("Valor") #promedio de la columna Valor por tipo de inmueble como datafra,
#ordenado de menor a mayor
print(type(valor_promedio_tipo_df)) #es un dataframe
valor_promedio_tipo_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# ...

# %%
valor_promedio_tipo_df.plot.bar(title="Valor promedio por tipo de inmueble")
# Out:
# <Axes: title={'center': 'Valor promedio por tipo de inmueble'}, xlabel='Tipo'>

# %%
valor_promedio_tipo_df.plot(kind="barh", figsize=(12,8), color="purple", title="Valor promedio por tipo de inmueble")
# Out:
# <Axes: title={'center': 'Valor promedio por tipo de inmueble'}, ylabel='Tipo'>

# %%
datos.Tipo.unique() #entrega los valores únicos de la columna Tipo
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales_lista = ['Conjunto Comercial/Sala', 'Edificio Completo',
       'Tienda/Salón', 'Casa Comercial',
       'Terreno Estándar', 'Cochera/Estacionamiento',
       'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial',
        'Hotel', 'Loteo/Condominio',
       'Industria']

# %%
inmuebles_comerciales = datos.query("@inmuebles_comerciales_lista in Tipo") #si alguno de los elementos de la lista están dentro del dataset
inmuebles_comerciales
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
inmuebles_residenciales = datos.query("@inmuebles_comerciales_lista not in Tipo")
inmuebles_residenciales
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
inmuebles_residenciales.head()
# Out:
#                  Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0            Cocineta           Condesa             1        0       0    40
# 1                Casa           Polanco             2        0       1   100
# 3        Departamento  Centro Histórico             1        0       0    15
# 4        Departamento         Del Valle             1        0       0    48
# 5  Casa de Condominio          Santa Fe             5        4       5   750
#
#      Valor  Condominio  Impuesto
# 0   5950.0      1750.0     210.0
# 1  24500.0         NaN       NaN
# 3   2800.0      1365.0      70.0
# 4   2800.0       805.0       NaN
# 5  77000.0         NaN       NaN

# %%
valor_promedio_tipo_res_df = inmuebles_residenciales.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
valor_promedio_tipo_res_df.plot(kind="barh", figsize=(12,8), color="purple", title="Valor promedio por tipo de inmueble residencial")
# Out:
# <Axes: title={'center': 'Valor promedio por tipo de inmueble residencial'}, ylabel='Tipo'>

# %%
valor_promedio_tipo_com_df = inmuebles_comerciales.groupby("Tipo")[["Valor"]].mean().sort_values("Valor")
valor_promedio_tipo_com_df.plot(kind="barh", figsize=(12,8), color="green", title="Valor promedio por tipo de inmueble comercial")
# Out:
# <Axes: title={'center': 'Valor promedio por tipo de inmueble comercial'}, ylabel='Tipo'>

# %% [markdown]
# ###Porcentaje de cada tipo de inmueble presente en la base de datos

# %%
inmuebles_residenciales.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
inmuebles_residenciales.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
inmuebles_residenciales.Tipo.value_counts(normalize=True) * 100 #entrega el porcentaje
# Out:
# Tipo
# Departamento             85.296666
# Cocineta                  4.194350
# Casa de Condominio        3.524178
# Casa                      3.148651
# Departamento en Hotel     2.628690
# Casa de Vecindad          0.912820
# Loft                      0.219539
# Rancho                    0.046219
# Estudio                   0.023109
# Posada/Chalé              0.005777
# Name: proportion, dtype: float64

# %%
type(inmuebles_residenciales.Tipo.value_counts(normalize=True))
# Out:
# pandas.core.series.Series

# %%
porcentaje_tipo = (inmuebles_residenciales.Tipo.value_counts(normalize=True)*100).to_frame("Porcentajes")
porcentaje_tipo.plot(kind="bar", figsize=(12,8),color="violet", xlabel="Tipos", ylabel="Porcentaje", title="Porcentaje de cada tipo de inmueble")
# Out:
# <Axes: title={'center': 'Porcentaje de cada tipo de inmueble'}, xlabel='Tipos', ylabel='Porcentaje'>

# %%
porcentaje_tipo
# Out:
#                        Porcentajes
# Tipo
# Departamento             85.296666
# Cocineta                  4.194350
# Casa de Condominio        3.524178
# Casa                      3.148651
# Departamento en Hotel     2.628690
# Casa de Vecindad          0.912820
# Loft                      0.219539
# Rancho                    0.046219
# Estudio                   0.023109
# Posada/Chalé              0.005777

# %%
solo_deptos = inmuebles_residenciales.query('Tipo == "Departamento"')
solo_deptos.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
solo_deptos.shape
# Out:
# (14764, 9)

# %% [markdown]
# ####Practicando

# %%
datos["Habitaciones"].mean() #promedio habitaciones
# Out:
# np.float64(1.7488555391903189)

# %%
len(datos["Colonia"].unique()) #cuántas colonias únicas existen
# Out:
# 88

# %%
datos["Colonia"].nunique() #cuántas colonias únicas existen
# Out:
# 88

# %%
colonias_caras = datos.groupby("Colonia")[["Valor"]].mean().sort_values("Valor", ascending=False).head(5)
colonias_caras
# Out:
#                               Valor
# Colonia
# San Juan Xalpa        420926.739130
# Nativitas             244684.395062
# La Merced             213292.770833
# Santa Marta Acatitla  166048.105263
# Villa de Cortés       135737.411765

# %%
colonias_caras.plot(kind="bar", figsize=(12,8), color="green", title="Colonias más caras")
# Out:
# <Axes: title={'center': 'Colonias más caras'}, xlabel='Colonia'>

# %% [markdown]
# ###Alterando los nombres de las columnas

# %%
inmuebles_residenciales["Tipo"].unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
inmuebles_residenciales["Tipo"].value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_ordenado_res = inmuebles_residenciales["Tipo"].value_counts(normalize=True).to_frame("Porcentaje").sort_values("Porcentaje")
porcentaje_ordenado_res
# Out:
#                        Porcentaje
# Tipo
# Posada/Chalé             0.000058
# Estudio                  0.000231
# Rancho                   0.000462
# Loft                     0.002195
# Casa de Vecindad         0.009128
# Departamento en Hotel    0.026287
# Casa                     0.031487
# Casa de Condominio       0.035242
# Cocineta                 0.041943
# Departamento             0.852967

# %%
porcentaje_ordenado_res.rename(columns={"Porcentaje": "Porcentaje_ordenado"}, inplace=True)
porcentaje_ordenado_res
# Out:
#                        Porcentaje_ordenado
# Tipo
# Posada/Chalé                      0.000058
# Estudio                           0.000231
# Rancho                            0.000462
# Loft                              0.002195
# Casa de Vecindad                  0.009128
# Departamento en Hotel             0.026287
# Casa                              0.031487
# Casa de Condominio                0.035242
# Cocineta                          0.041943
# Departamento                      0.852967

# %% [markdown]
# ##Tratar Valores Nulos

# %%
datos.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 0      False    False         False    False   False  False  False
# 1      False    False         False    False   False  False  False
# 2      False    False         False    False   False  False  False
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25116  False    False         False    False   False  False  False
# 25117  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
# 25120  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 0           False     False
# 1            True      True
# 2           False     False
# 3           False     False
# ...

# %%
datos.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor             14
# Condominio      2626
# Impuesto        7084
# dtype: int64

# %%
datos_sin_nulos = datos.fillna(0) #reemplaza valores nulos por 0
datos_sin_nulos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos_sin_nulos.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ##Remover registros inconsistentes

# %% [markdown]
# ###Existen varias formas de tratar datos nulos con Pandas. Algunas de las formas principales son:
#
# Eliminar los datos nulos: Es posible eliminar las filas o columnas que contienen valores nulos utilizando el método dropna(). Este método elimina todas las filas o columnas que tienen al menos un valor nulo.
#
# Llenar los datos nulos: Utilizando el método fillna(), podemos llenar los valores nulos con un valor específico. Además, también es posible utilizar argumentos específicos del método fillna(), como method="ffill" o method="bfill", para llenar los valores nulos con el valor anterior o posterior, respectivamente.
#
# Interpolar los datos nulos: Es posible utilizar el método interpolate() para llenar los valores nulos con valores interpolados, es decir, valores calculados a partir de los valores vecinos.

# %% [markdown]
# ###Remover departamentos con valor igual a 0

# %%
datos_sin_nulos.query("Valor==0 | Condominio==0")
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 1                         Casa               Polanco             2        0
# 5           Casa de Condominio              Santa Fe             5        4
# 7                 Departamento      Centro Histórico             1        0
# 11           Edificio Completo                  Roma             0        0
# 24     Conjunto Comercial/Sala              Santa Fe             0        1
# ...                        ...                   ...           ...      ...
# 25055  Conjunto Comercial/Sala               Polanco             1        3
# 25086                     Casa             Zacatenco             2        1
# 25098             Tienda/Salón  Lomas de Chapultepec             0        0
# 25099                     Casa      Centro Histórico             5        0
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
deptos_sin_nulos = solo_deptos.fillna(0)
deptos_sin_nulos
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
deptos_sin_nulos.query("Valor==0 | Condominio==0")
# Out:
#                Tipo                 Colonia  Habitaciones  Garages  Suites  \
# 7      Departamento        Centro Histórico             1        0       0
# 49     Departamento                Santa Fe             2        1       1
# 74     Departamento  Ciudad de los Deportes             2        0       0
# 116    Departamento              El Rosedal             2        1       0
# 136    Departamento                Santa Fe             1        1       1
# ...             ...                     ...           ...      ...     ...
# 24721  Departamento                Doctores             2        0       0
# 24736  Departamento                 Condesa             1        0       0
# 24866  Departamento                 Condesa             3        0       0
# 24892  Departamento             Loma Bonita             1        0       0
# 25014  Departamento           Culhuacán CTM             3        0       1
#
#        Area    Valor  Condominio  Impuesto
# ...

# %%
indices_remover = deptos_sin_nulos.query("Valor==0 | Condominio==0").index
indices_remover
# Out:
# Index([    7,    49,    74,   116,   136,   185,   199,   432,   504,   527,
#        ...
#        24426, 24555, 24563, 24597, 24671, 24721, 24736, 24866, 24892, 25014],
#       dtype='int64', length=500)

# %%
deptos_sin_nulos.drop(indices_remover, axis= 0, inplace=True) #axis = 0 son las filas

# %%
deptos_sin_nulos.query("Valor==0 | Condominio==0").index
# Out:
# Index([], dtype='int64')

# %%
deptos_sin_nulos.Tipo.unique()
# Out:
# array(['Departamento'], dtype=object)

# %%
deptos_sin_nulos.drop("Tipo", axis=1, inplace=True) #borra la columna de tipo ya que todos son departamentos
deptos_sin_nulos.sample(5)
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 1761           San Jerónimo             2        1       0    87   8750.0
# 7312                Condesa             1        0       0    20   4200.0
# 11795               Napoles             1        0       0    52   5250.0
# 18831  Bosques de las Lomas             2        1       0    56  12250.0
# 24532             Nativitas             2        0       0    57   4200.0
#
#        Condominio  Impuesto
# 1761       2789.5       0.0
# 7312       1155.0     101.5
# 11795      2128.0     269.5
# 18831      5250.0     973.0
# 24532      2065.0     210.0

# %% [markdown]
# ##Aplicar Filtros

# %% [markdown]
# ###Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.

# %%
filtro_1_dormitorio = deptos_sin_nulos["Habitaciones"] == 1
filtro_1_dormitorio
# Out:
# 3         True
# 4         True
# 8         True
# 10       False
# 13       False
#          ...
# 25111    False
# 25113    False
# 25114     True
# 25118    False
# 25119    False
# Name: Habitaciones, Length: 14264, dtype: bool

# %%
deptos_1_dormitorio = deptos_sin_nulos[filtro_1_dormitorio]
deptos_1_dormitorio
# Out:
#                     Colonia  Habitaciones  Garages  Suites  Area    Valor  \
# 3          Centro Histórico             1        0       0    15   2800.0
# 4                 Del Valle             1        0       0    48   2800.0
# 8                   Condesa             1        0       1    40   7000.0
# 19                 Narvarte             1        0       0    48   2625.0
# 37         Centro Histórico             1        0       0    27   2625.0
# ...                     ...           ...      ...     ...   ...      ...
# 25090              Coyoacán             1        0       0    55   7000.0
# 25092              Santa Fe             1        1       0    62   5950.0
# 25100  Lomas de Chapultepec             1        1       1    50  15050.0
# 25103               Condesa             1        0       0    50   6825.0
# 25114              Narvarte             1        0       0    28   3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# ...

# %%
deptos_menor4200 = deptos_1_dormitorio["Valor"] < 4200
deptos_1_dormitorio[deptos_menor4200]
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
deptos_1_dormitorio[deptos_menor4200].max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 1
# Garages                      1
# Suites                       1
# Area                        99
# Valor                   4025.0
# Condominio              9275.0
# Impuesto                3150.0
# dtype: object

# %%
deptos_1_dormitorio_menor4200 = deptos_sin_nulos.query("Habitaciones==1 & Valor<4200") #más corta
deptos_1_dormitorio_menor4200
# Out:
#                 Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 3      Centro Histórico             1        0       0    15  2800.0
# 4             Del Valle             1        0       0    48  2800.0
# 19             Narvarte             1        0       0    48  2625.0
# 37     Centro Histórico             1        0       0    27  2625.0
# 61     Centro Histórico             1        1       0    37  3850.0
# ...                 ...           ...      ...     ...   ...     ...
# 24710         Nativitas             1        0       0    40  3150.0
# 24872        Peralvillo             1        0       1    69  3150.0
# 24880        La Condesa             1        0       0    46  3850.0
# 24943              Roma             1        0       0    21  3500.0
# 25114          Narvarte             1        0       0    28  3500.0
#
#        Condominio  Impuesto
# 3          1365.0      70.0
# 4           805.0       0.0
# 19         2702.0      87.5
# ...

# %%
deptos_1_dormitorio_menor4200.max()
# Out:
# Colonia         Álvaro Obregón
# Habitaciones                 1
# Garages                      1
# Suites                       1
# Area                        99
# Valor                   4025.0
# Condominio              9275.0
# Impuesto                3150.0
# dtype: object

# %% [markdown]
# ###Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².

# %%
deptos_2dormitorios_menor10500_mayor70m2 = deptos_sin_nulos.query("Habitaciones>=2 & Valor<10500 & Area>70")
deptos_2dormitorios_menor10500_mayor70m2
# Out:
#          Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 14      Narvarte             2        1       0   110  6650.0      2450.0
# 16      Narvarte             2        1       0    78  7000.0      2450.0
# 21          Roma             2        1       0    76  8750.0      2590.0
# 33      Santa Fe             3        1       1    72  8225.0      2100.0
# 58      Santa Fe             3        2       1   104  9100.0      4774.0
# ...          ...           ...      ...     ...   ...     ...         ...
# 25028  Del Valle             2        0       1    90  7700.0      1890.0
# 25062   Santa Fe             2        1       1    72  5950.0      3045.0
# 25063   Narvarte             3        1       0    75  6650.0      3010.0
# 25105   Santa Fe             2        1       1    85  7875.0      5463.5
# 25106   Santa Fe             3        2       0    98  8050.0      3104.5
#
#        Impuesto
# 14        483.0
# 16          0.0
# 21          0.0
# ...

# %% [markdown]
# ##Guardar datos

# %%
deptos_1_dormitorio_menor4200.to_csv("/content/drive/MyDrive/deptos_1_dormitorio_menor4200.csv", index=False)

# %%
nuevo = pd.read_csv("/content/drive/MyDrive/deptos_1_dormitorio_menor4200.csv")
nuevo
# Out:
#               Colonia  Habitaciones  Garages  Suites  Area   Valor  \
# 0    Centro Histórico             1        0       0    15  2800.0
# 1           Del Valle             1        0       0    48  2800.0
# 2            Narvarte             1        0       0    48  2625.0
# 3    Centro Histórico             1        0       0    27  2625.0
# 4    Centro Histórico             1        1       0    37  3850.0
# ..                ...           ...      ...     ...   ...     ...
# 356         Nativitas             1        0       0    40  3150.0
# 357        Peralvillo             1        0       1    69  3150.0
# 358        La Condesa             1        0       0    46  3850.0
# 359              Roma             1        0       0    21  3500.0
# 360          Narvarte             1        0       0    28  3500.0
#
#      Condominio  Impuesto
# 0        1365.0      70.0
# 1         805.0       0.0
# 2        2702.0      87.5
# 3        1298.5      66.5
# ...

# %%
deptos_2dormitorios_menor10500_mayor70m2.to_csv("/content/drive/MyDrive/deptos_2dormitorios_menor10500_mayor70m2.csv", index=False, sep=';')
pd.read_csv("/content/drive/MyDrive/deptos_2dormitorios_menor10500_mayor70m2.csv", sep=';')
# Out:
#         Colonia  Habitaciones  Garages  Suites  Area   Valor  Condominio  \
# 0      Narvarte             2        1       0   110  6650.0      2450.0
# 1      Narvarte             2        1       0    78  7000.0      2450.0
# 2          Roma             2        1       0    76  8750.0      2590.0
# 3      Santa Fe             3        1       1    72  8225.0      2100.0
# 4      Santa Fe             3        2       1   104  9100.0      4774.0
# ...         ...           ...      ...     ...   ...     ...         ...
# 2638  Del Valle             2        0       1    90  7700.0      1890.0
# 2639   Santa Fe             2        1       1    72  5950.0      3045.0
# 2640   Narvarte             3        1       0    75  6650.0      3010.0
# 2641   Santa Fe             2        1       1    85  7875.0      5463.5
# 2642   Santa Fe             3        2       0    98  8050.0      3104.5
#
#       Impuesto
# 0        483.0
# 1          0.0
# 2          0.0
# 3        245.0
# ...

# %% [markdown]
# ##Práctica

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
datos_alumnos = pd.read_csv(url)

# %%
datos_alumnos.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
datos_alumnos.tail()
# Out:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %%
datos_alumnos.shape
# Out:
# (18, 4)

# %%
# Visualizar los nombres de las columnas
datos_alumnos.columns

# Seleccionar una columna
datos_alumnos['Nombre']

# Seleccionar múltiples columnas
datos_alumnos[['Edad', 'Nota']]

# Verificar los tipos de datos en cada columna
datos.dtypes
# Out:
# Tipo             object
# Colonia          object
# Habitaciones      int64
# Garages           int64
# Suites            int64
# Area              int64
# Valor           float64
# Condominio      float64
# Impuesto        float64
# dtype: object

# %% [markdown]
# ####Saber más
# La idea detrás de groupby es dividir los datos en grupos basados en los criterios seleccionados y luego aplicar una operación a estos grupos. Esta operación puede ser una función de agregación, como suma, promedio, recuento, desviación estándar, entre otras, o incluso una operación personalizada definida por el usuario.
#
# Este método tiene varios parámetros, algunos de los cuales son:
#
# by: Este es el parámetro más común y se utiliza para especificar la columna o columnas por las cuales queremos agrupar. Como argumento, podemos pasar el nombre de una columna o una lista de nombres de columnas;
#
# axis: Utilizamos este parámetro para especificar el eje a lo largo del cual queremos agrupar. El valor predeterminado es 0, lo que significa que se agruparán las filas. Si deseamos agrupar las columnas, debemos establecer este parámetro en 1;
#
# sort: Este parámetro es un booleano (True o False) que indica si los grupos deben ordenarse por el valor de la columna de agrupación. El valor predeterminado es True;
#
# dropna: Utilizamos este parámetro para controlar si los valores faltantes (NaN) se eliminarán o no durante el proceso de agrupación. El valor predeterminado es True.

# %%
import pandas as pd

animales = pd.DataFrame({
   'Animal': ['Perro', 'Gato', 'Elefante', 'Perro', 'Gato', 'Elefante'],
   'Color': ['Negro', 'Blanco', 'Gris', 'Marrón', 'Negro', 'Marrón'],
   'Cantidad': [2, 3, 1, 4, 2, 2]
})
animales
# Out:
#      Animal   Color  Cantidad
# 0     Perro   Negro         2
# 1      Gato  Blanco         3
# 2  Elefante    Gris         1
# 3     Perro  Marrón         4
# 4      Gato   Negro         2
# 5  Elefante  Marrón         2

# %%
animales.groupby('Animal').sum(numeric_only=True)
# Out:
#           Cantidad
# Animal
# Elefante         3
# Gato             5
# Perro            6

# %%
animales.groupby(['Animal', 'Color'])[['Cantidad']].sum()
# Out:
#                  Cantidad
# Animal   Color
# Elefante Gris           1
#          Marrón         2
# Gato     Blanco         3
#          Negro          2
# Perro    Marrón         4
#          Negro          2
